# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cr_db = pd.read_csv('credit_risk.csv')

# %%
cr_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# over_draft                1000 non-null object
# credit_usage              1000 non-null int64
# credit_history            1000 non-null object
# purpose                   1000 non-null object
# current_balance           1000 non-null int64
# Average_Credit_Balance    1000 non-null object
# employment                1000 non-null object
# location                  1000 non-null int64
# personal_status           1000 non-null object
# other_parties             1000 non-null object
# residence_since           1000 non-null int64
# property_magnitude        1000 non-null object
# cc_age                    1000 non-null int64
# other_payment_plans       1000 non-null object
# housing                   1000 non-null object
# existing_credits          1000 non-null int64
# job                       1000 non-null object
# num_dependents            1000 non-null int64
# own_telephone             1000 non-null object
# foreign_worker            1000 non-null object
# class                     1000 non-null object
# dtypes: int64(7), object(14)
# memory usage: 164.1+ KB

# %% [markdown]
# # Selecting the feature and target variables

# %%
# Predictor attributes
X = cr_db.columns.drop('class')

# %%
# Target variables
y = cr_db['class']

# %% [markdown]
# # Encoding the features

# %%
encoded_X = pd.get_dummies(cr_db[X])

# %%
encoded_X.columns
# Out:
# Index(['credit_usage', 'current_balance', 'location', 'residence_since',
#        'cc_age', 'existing_credits', 'num_dependents', 'over_draft_0<=X<200',
#        'over_draft_<0', 'over_draft_>=200', 'over_draft_no checking',
#        'credit_history_all paid',
#        'credit_history_critical/other existing credit',
#        'credit_history_delayed previously', 'credit_history_existing paid',
#        'credit_history_no credits/all paid', 'purpose_business',
#        'purpose_domestic appliance', 'purpose_education',
#        'purpose_furniture/equipment', 'purpose_new car', 'purpose_other',
#        'purpose_radio/tv', 'purpose_repairs', 'purpose_retraining',
#        'purpose_used car', 'Average_Credit_Balance_100<=X<500',
#        'Average_Credit_Balance_500<=X<1000', 'Average_Credit_Balance_<100',
#        'Average_Credit_Balance_>=1000',
#        'Average_Credit_Balance_no known savings', 'employment_1<=X<4',
#        'employment_4<=X<7', 'employment_<1', 'employment_>=7',
#        'employment_unemployed', 'personal_status_female div/dep/mar',
#        'personal_status_male div/sep', 'personal_status_male mar/wid',
#        'personal_status_male single', 'other_parties_co applicant',
#        'other_parties_guarantor', 'other_parties_none',
#        'property_magnitude_car', 'property_magnitude_life insurance',
#        'property_magnitude_no known property',
#        'property_magnitude_real estate', 'other_payment_plans_bank',
#        'other_payment_plans_none', 'other_payment_plans_stores',
#        'housing_for free', 'housing_own', 'housing_rent',
#        'job_high qualif/self emp/mgmt', 'job_skilled',
#        'job_unemp/unskilled non res', 'job_unskilled resident',
#        'own_telephone_none', 'own_telephone_yes', 'foreign_worker_no',
#        'foreign_worker_yes'],
#       dtype='object')

# %% [markdown]
# # Building model

# %%
# Spliting the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(encoded_X, y,test_size=0.20,random_state=100)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier().fit(X_train, y_train)

# %%
# Train predictions
train_pred = model.predict(X_train)

# %%
# Test predictions
test_pred = model.predict(X_test)

# %%
# Train accuracy 
model.score(X_train, y_train)
# Out:
# 1.0

# %%
# Test accuracy 
model.score(X_test, y_test)
# Out:
# 0.675

# %% [markdown]
# # Visualize the decision tree

# %%
from sklearn.tree import export_graphviz

# %%
model.classes_
# Out:
# array(['bad', 'good'], dtype=object)

# %%
dot_data = export_graphviz(model, out_file=None,
                          feature_names=encoded_X.columns,  
                          class_names=model.classes_,  
                          )

# %%
print(dot_data)
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="over_draft_no checking <= 0.5\ngini = 0.424\nsamples = 800\nvalue = [244, 556]\nclass = good"] ;
# 1 [label="credit_usage <= 22.5\ngini = 0.489\nsamples = 482\nvalue = [206, 276]\nclass = good"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="credit_history_all paid <= 0.5\ngini = 0.449\nsamples = 279\nvalue = [95, 184]\nclass = good"] ;
# 1 -> 2 ;
# 3 [label="credit_history_no credits/all paid <= 0.5\ngini = 0.428\nsamples = 261\nvalue = [81, 180]\nclass = good"] ;
# 2 -> 3 ;
# 4 [label="current_balance <= 7442.5\ngini = 0.413\nsamples = 250\nvalue = [73, 177]\nclass = good"] ;
# 3 -> 4 ;
# 5 [label="credit_usage <= 8.5\ngini = 0.404\nsamples = 246\nvalue = [69, 177]\nclass = good"] ;
# 4 -> 5 ;
# 6 [label="job_high qualif/self emp/mgmt <= 0.5\ngini = 0.149\nsamples = 37\nvalue = [3, 34]\nclass = good"] ;
# 5 -> 6 ;
# 7 [label="purpose_education <= 0.5\ngini = 0.059\nsamples = 33\nvalue = [1, 32]\nclass = good"] ;
# 6 -> 7 ;
# 8 [label="gini = 0.0\nsamples = 31\nvalue = [0, 31]\nclass = good"] ;
# 7 -> 8 ;
# 9 [label="cc_age <= 36.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 7 -> 9 ;
# 10 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 9 -> 10 ;
# 11 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 9 -> 11 ;
# 12 [label="residence_since <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = bad"] ;
# 6 -> 12 ;
# 13 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 12 -> 13 ;
# 14 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 12 -> 14 ;
# 15 [label="current_balance <= 1513.0\ngini = 0.432\nsamples = 209\nvalue = [66, 143]\nclass = good"] ;
# 5 -> 15 ;
# 16 [label="property_magnitude_real estate <= 0.5\ngini = 0.491\nsamples = 97\nvalue = [42, 55]\nclass = good"] ;
# 15 -> 16 ;
# 17 [label="purpose_furniture/equipment <= 0.5\ngini = 0.482\nsamples = 52\nvalue = [31, 21]\nclass = bad"] ;
# 16 -> 17 ;
# 18 [label="cc_age <= 62.0\ngini = 0.405\nsamples = 39\nvalue = [28, 11]\nclass = bad"] ;
# 17 -> 18 ;
# 19 [label="current_balance <= 515.5\ngini = 0.32\nsamples = 35\nvalue = [28, 7]\nclass = bad"] ;
# 18 -> 19 ;
# 20 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 19 -> 20 ;
# 21 [label="credit_usage <= 11.5\ngini = 0.291\nsamples = 34\nvalue = [28, 6]\nclass = bad"] ;
# 19 -> 21 ;
# 22 [label="housing_own <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = bad"] ;
# 21 -> 22 ;
# 23 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = bad"] ;
# 22 -> 23 ;
# 24 [label="credit_usage <= 9.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = good"] ;
# 22 -> 24 ;
# 25 [label="residence_since <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 24 -> 25 ;
# 26 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 25 -> 26 ;
# 27 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 25 -> 27 ;
# 28 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 24 -> 28 ;
# 29 [label="current_balance <= 1387.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]\nclass = bad"] ;
# 21 -> 29 ;
# 30 [label="purpose_business <= 0.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = bad"] ;
# 29 -> 30 ;
# 31 [label="gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = bad"] ;
# 30 -> 31 ;
# 32 [label="job_unskilled resident <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 30 -> 32 ;
# 33 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 32 -> 33 ;
# 34 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 32 -> 34 ;
# 35 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 29 -> 35 ;
# 36 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 35 -> 36 ;
# 37 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 35 -> 37 ;
# 38 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = good"] ;
# 18 -> 38 ;
# 39 [label="credit_usage <= 9.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = good"] ;
# 17 -> 39 ;
# 40 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 39 -> 40 ;
# 41 [label="employment_unemployed <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = good"] ;
# 39 -> 41 ;
# 42 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = good"] ;
# 41 -> 42 ;
# 43 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 41 -> 43 ;
# 44 [label="residence_since <= 3.5\ngini = 0.369\nsamples = 45\nvalue = [11, 34]\nclass = good"] ;
# 16 -> 44 ;
# 45 [label="other_parties_guarantor <= 0.5\ngini = 0.459\nsamples = 28\nvalue = [10, 18]\nclass = good"] ;
# 44 -> 45 ;
# 46 [label="credit_usage <= 16.5\ngini = 0.491\nsamples = 23\nvalue = [10, 13]\nclass = good"] ;
# 45 -> 46 ;
# 47 [label="personal_status_male single <= 0.5\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = good"] ;
# 46 -> 47 ;
# 48 [label="purpose_new car <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = good"] ;
# 47 -> 48 ;
# 49 [label="cc_age <= 26.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = good"] ;
# 48 -> 49 ;
# 50 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 49 -> 50 ;
# 51 [label="over_draft_>=200 <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = good"] ;
# 49 -> 51 ;
# 52 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = good"] ;
# 51 -> 52 ;
# 53 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 51 -> 53 ;
# 54 [label="Average_Credit_Balance_>=1000 <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = bad"] ;
# 48 -> 54 ;
# 55 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = bad"] ;
# 54 -> 55 ;
# 56 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 54 -> 56 ;
# 57 [label="Average_Credit_Balance_<100 <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = good"] ;
# 47 -> 57 ;
# 58 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 57 -> 58 ;
# 59 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = good"] ;
# 57 -> 59 ;
# 60 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 46 -> 60 ;
# 61 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 45 -> 61 ;
# 62 [label="other_payment_plans_stores <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = good"] ;
# 44 -> 62 ;
# 63 [label="gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = good"] ;
# 62 -> 63 ;
# 64 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 62 -> 64 ;
# 65 [label="other_parties_co applicant <= 0.5\ngini = 0.337\nsamples = 112\nvalue = [24, 88]\nclass = good"] ;
# 15 -> 65 ;
# 66 [label="credit_usage <= 14.5\ngini = 0.308\nsamples = 105\nvalue = [20, 85]\nclass = good"] ;
# 65 -> 66 ;
# 67 [label="current_balance <= 5619.5\ngini = 0.165\nsamples = 44\nvalue = [4, 40]\nclass = good"] ;
# 66 -> 67 ;
# 68 [label="cc_age <= 23.5\ngini = 0.13\nsamples = 43\nvalue = [3, 40]\nclass = good"] ;
# 67 -> 68 ;
# 69 [label="personal_status_male mar/wid <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = good"] ;
# 68 -> 69 ;
# 70 [label="credit_usage <= 10.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = good"] ;
# 69 -> 70 ;
# 71 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 70 -> 71 ;
# 72 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 70 -> 72 ;
# 73 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 69 -> 73 ;
# 74 [label="cc_age <= 57.5\ngini = 0.054\nsamples = 36\nvalue = [1, 35]\nclass = good"] ;
# 68 -> 74 ;
# 75 [label="gini = 0.0\nsamples = 34\nvalue = [0, 34]\nclass = good"] ;
# 74 -> 75 ;
# 76 [label="job_skilled <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 74 -> 76 ;
# 77 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 76 -> 77 ;
# 78 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 76 -> 78 ;
# 79 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 67 -> 79 ;
# 80 [label="over_draft_0<=X<200 <= 0.5\ngini = 0.387\nsamples = 61\nvalue = [16, 45]\nclass = good"] ;
# 66 -> 80 ;
# 81 [label="property_magnitude_real estate <= 0.5\ngini = 0.478\nsamples = 33\nvalue = [13, 20]\nclass = good"] ;
# 80 -> 81 ;
# 82 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.393\nsamples = 26\nvalue = [7, 19]\nclass = good"] ;
# 81 -> 82 ;
# 83 [label="Average_Credit_Balance_<100 <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [6, 8]\nclass = good"] ;
# 82 -> 83 ;
# 84 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 83 -> 84 ;
# 85 [label="own_telephone_yes <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = bad"] ;
# 83 -> 85 ;
# 86 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = bad"] ;
# 85 -> 86 ;
# 87 [label="other_parties_none <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 85 -> 87 ;
# 88 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 87 -> 88 ;
# 89 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 87 -> 89 ;
# 90 [label="employment_1<=X<4 <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = good"] ;
# 82 -> 90 ;
# 91 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = good"] ;
# 90 -> 91 ;
# 92 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 90 -> 92 ;
# 93 [label="other_parties_guarantor <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = bad"] ;
# 81 -> 93 ;
# 94 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = bad"] ;
# 93 -> 94 ;
# 95 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 93 -> 95 ;
# 96 [label="personal_status_male div/sep <= 0.5\ngini = 0.191\nsamples = 28\nvalue = [3, 25]\nclass = good"] ;
# 80 -> 96 ;
# 97 [label="Average_Credit_Balance_100<=X<500 <= 0.5\ngini = 0.08\nsamples = 24\nvalue = [1, 23]\nclass = good"] ;
# 96 -> 97 ;
# 98 [label="gini = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = good"] ;
# 97 -> 98 ;
# 99 [label="residence_since <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 97 -> 99 ;
# 100 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 99 -> 100 ;
# 101 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 99 -> 101 ;
# 102 [label="residence_since <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = bad"] ;
# 96 -> 102 ;
# 103 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 102 -> 103 ;
# 104 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 102 -> 104 ;
# 105 [label="cc_age <= 35.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = bad"] ;
# 65 -> 105 ;
# 106 [label="location <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 105 -> 106 ;
# 107 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 106 -> 107 ;
# 108 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 106 -> 108 ;
# 109 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 105 -> 109 ;
# 110 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = bad"] ;
# 4 -> 110 ;
# 111 [label="own_telephone_yes <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = bad"] ;
# 3 -> 111 ;
# 112 [label="gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = bad"] ;
# 111 -> 112 ;
# 113 [label="location <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 111 -> 113 ;
# 114 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 113 -> 114 ;
# 115 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 113 -> 115 ;
# 116 [label="purpose_radio/tv <= 0.5\ngini = 0.346\nsamples = 18\nvalue = [14, 4]\nclass = bad"] ;
# 2 -> 116 ;
# 117 [label="gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = bad"] ;
# 116 -> 117 ;
# 118 [label="cc_age <= 32.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = good"] ;
# 116 -> 118 ;
# 119 [label="over_draft_<0 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 118 -> 119 ;
# 120 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 119 -> 120 ;
# 121 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 119 -> 121 ;
# 122 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 118 -> 122 ;
# 123 [label="Average_Credit_Balance_<100 <= 0.5\ngini = 0.496\nsamples = 203\nvalue = [111, 92]\nclass = bad"] ;
# 1 -> 123 ;
# 124 [label="credit_history_existing paid <= 0.5\ngini = 0.468\nsamples = 67\nvalue = [25, 42]\nclass = good"] ;
# 123 -> 124 ;
# 125 [label="job_unskilled resident <= 0.5\ngini = 0.298\nsamples = 33\nvalue = [6, 27]\nclass = good"] ;
# 124 -> 125 ;
# 126 [label="existing_credits <= 3.5\ngini = 0.191\nsamples = 28\nvalue = [3, 25]\nclass = good"] ;
# 125 -> 126 ;
# 127 [label="purpose_other <= 0.5\ngini = 0.137\nsamples = 27\nvalue = [2, 25]\nclass = good"] ;
# 126 -> 127 ;
# 128 [label="num_dependents <= 1.5\ngini = 0.077\nsamples = 25\nvalue = [1, 24]\nclass = good"] ;
# 127 -> 128 ;
# 129 [label="gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = good"] ;
# 128 -> 129 ;
# 130 [label="over_draft_0<=X<200 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 128 -> 130 ;
# 131 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 130 -> 131 ;
# 132 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 130 -> 132 ;
# 133 [label="location <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 127 -> 133 ;
# 134 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 133 -> 134 ;
# 135 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 133 -> 135 ;
# 136 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 126 -> 136 ;
# 137 [label="credit_history_delayed previously <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = bad"] ;
# 125 -> 137 ;
# 138 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 137 -> 138 ;
# 139 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 137 -> 139 ;
# 140 [label="Average_Credit_Balance_100<=X<500 <= 0.5\ngini = 0.493\nsamples = 34\nvalue = [19, 15]\nclass = bad"] ;
# 124 -> 140 ;
# 141 [label="purpose_new car <= 0.5\ngini = 0.48\nsamples = 20\nvalue = [8, 12]\nclass = good"] ;
# 140 -> 141 ;
# 142 [label="job_high qualif/self emp/mgmt <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = good"] ;
# 141 -> 142 ;
# 143 [label="cc_age <= 21.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]\nclass = good"] ;
# 142 -> 143 ;
# 144 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 143 -> 144 ;
# 145 [label="other_parties_none <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = good"] ;
# 143 -> 145 ;
# 146 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 145 -> 146 ;
# 147 [label="employment_<1 <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = good"] ;
# 145 -> 147 ;
# 148 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = good"] ;
# 147 -> 148 ;
# 149 [label="property_magnitude_life insurance <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 147 -> 149 ;
# 150 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 149 -> 150 ;
# 151 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 149 -> 151 ;
# 152 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 142 -> 152 ;
# 153 [label="cc_age <= 26.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = bad"] ;
# 141 -> 153 ;
# 154 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 153 -> 154 ;
# 155 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = bad"] ;
# 153 -> 155 ;
# 156 [label="credit_usage <= 27.0\ngini = 0.337\nsamples = 14\nvalue = [11, 3]\nclass = bad"] ;
# 140 -> 156 ;
# 157 [label="over_draft_<0 <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = bad"] ;
# 156 -> 157 ;
# 158 [label="housing_rent <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 157 -> 158 ;
# 159 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 158 -> 159 ;
# 160 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 158 -> 160 ;
# 161 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 157 -> 161 ;
# 162 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = bad"] ;
# 156 -> 162 ;
# 163 [label="over_draft_>=200 <= 0.5\ngini = 0.465\nsamples = 136\nvalue = [86, 50]\nclass = bad"] ;
# 123 -> 163 ;
# 164 [label="credit_usage <= 47.5\ngini = 0.439\nsamples = 126\nvalue = [85, 41]\nclass = bad"] ;
# 163 -> 164 ;
# 165 [label="purpose_used car <= 0.5\ngini = 0.478\nsamples = 99\nvalue = [60, 39]\nclass = bad"] ;
# 164 -> 165 ;
# 166 [label="cc_age <= 62.5\ngini = 0.447\nsamples = 83\nvalue = [55, 28]\nclass = bad"] ;
# 165 -> 166 ;
# 167 [label="location <= 3.5\ngini = 0.436\nsamples = 81\nvalue = [55, 26]\nclass = bad"] ;
# 166 -> 167 ;
# 168 [label="own_telephone_yes <= 0.5\ngini = 0.489\nsamples = 40\nvalue = [23, 17]\nclass = bad"] ;
# 167 -> 168 ;
# 169 [label="residence_since <= 3.5\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = good"] ;
# 168 -> 169 ;
# 170 [label="employment_>=7 <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = good"] ;
# 169 -> 170 ;
# 171 [label="cc_age <= 44.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = good"] ;
# 170 -> 171 ;
# 172 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = good"] ;
# 171 -> 172 ;
# 173 [label="credit_history_existing paid <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 171 -> 173 ;
# 174 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 173 -> 174 ;
# 175 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 173 -> 175 ;
# 176 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 170 -> 176 ;
# 177 [label="employment_4<=X<7 <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = bad"] ;
# 169 -> 177 ;
# 178 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = bad"] ;
# 177 -> 178 ;
# 179 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 177 -> 179 ;
# 180 [label="credit_usage <= 33.0\ngini = 0.32\nsamples = 20\nvalue = [16, 4]\nclass = bad"] ;
# 168 -> 180 ;
# 181 [label="purpose_education <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = bad"] ;
# 180 -> 181 ;
# 182 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = bad"] ;
# 181 -> 182 ;
# 183 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 181 -> 183 ;
# 184 [label="cc_age <= 32.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = bad"] ;
# 180 -> 184 ;
# 185 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 184 -> 185 ;
# 186 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 184 -> 186 ;
# 187 [label="housing_own <= 0.5\ngini = 0.343\nsamples = 41\nvalue = [32, 9]\nclass = bad"] ;
# 167 -> 187 ;
# 188 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = bad"] ;
# 187 -> 188 ;
# 189 [label="employment_>=7 <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]\nclass = bad"] ;
# 187 -> 189 ;
# 190 [label="purpose_furniture/equipment <= 0.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]\nclass = bad"] ;
# 189 -> 190 ;
# 191 [label="residence_since <= 1.5\ngini = 0.208\nsamples = 17\nvalue = [15, 2]\nclass = bad"] ;
# 190 -> 191 ;
# 192 [label="over_draft_0<=X<200 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 191 -> 192 ;
# 193 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 192 -> 193 ;
# 194 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 192 -> 194 ;
# 195 [label="gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = bad"] ;
# 191 -> 195 ;
# 196 [label="current_balance <= 4674.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 190 -> 196 ;
# 197 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 196 -> 197 ;
# 198 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 196 -> 198 ;
# 199 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = good"] ;
# 189 -> 199 ;
# 200 [label="cc_age <= 42.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = bad"] ;
# 199 -> 200 ;
# 201 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 200 -> 201 ;
# 202 [label="purpose_new car <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 200 -> 202 ;
# 203 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 202 -> 203 ;
# 204 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 202 -> 204 ;
# 205 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 199 -> 205 ;
# 206 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 166 -> 206 ;
# 207 [label="current_balance <= 8097.5\ngini = 0.43\nsamples = 16\nvalue = [5, 11]\nclass = good"] ;
# 165 -> 207 ;
# 208 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = good"] ;
# 207 -> 208 ;
# 209 [label="other_payment_plans_none <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = bad"] ;
# 207 -> 209 ;
# 210 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 209 -> 210 ;
# 211 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = bad"] ;
# 209 -> 211 ;
# 212 [label="residence_since <= 1.5\ngini = 0.137\nsamples = 27\nvalue = [25, 2]\nclass = bad"] ;
# 164 -> 212 ;
# 213 [label="personal_status_male single <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 212 -> 213 ;
# 214 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 213 -> 214 ;
# 215 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 213 -> 215 ;
# 216 [label="property_magnitude_life insurance <= 0.5\ngini = 0.077\nsamples = 25\nvalue = [24, 1]\nclass = bad"] ;
# 212 -> 216 ;
# 217 [label="gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = bad"] ;
# 216 -> 217 ;
# 218 [label="num_dependents <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 216 -> 218 ;
# 219 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 218 -> 219 ;
# 220 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 218 -> 220 ;
# 221 [label="employment_1<=X<4 <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = good"] ;
# 163 -> 221 ;
# 222 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = good"] ;
# 221 -> 222 ;
# 223 [label="property_magnitude_car <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 221 -> 223 ;
# 224 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 223 -> 224 ;
# 225 [label="current_balance <= 5029.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 223 -> 225 ;
# 226 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 225 -> 226 ;
# 227 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 225 -> 227 ;
# 228 [label="other_payment_plans_none <= 0.5\ngini = 0.21\nsamples = 318\nvalue = [38, 280]\nclass = good"] ;
# 0 -> 228 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 229 [label="cc_age <= 44.5\ngini = 0.444\nsamples = 45\nvalue = [15, 30]\nclass = good"] ;
# 228 -> 229 ;
# 230 [label="credit_history_no credits/all paid <= 0.5\ngini = 0.482\nsamples = 37\nvalue = [15, 22]\nclass = good"] ;
# 229 -> 230 ;
# 231 [label="location <= 1.5\ngini = 0.467\nsamples = 35\nvalue = [13, 22]\nclass = good"] ;
# 230 -> 231 ;
# 232 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 231 -> 232 ;
# 233 [label="Average_Credit_Balance_500<=X<1000 <= 0.5\ngini = 0.491\nsamples = 30\nvalue = [13, 17]\nclass = good"] ;
# 231 -> 233 ;
# 234 [label="purpose_education <= 0.5\ngini = 0.466\nsamples = 27\nvalue = [10, 17]\nclass = good"] ;
# 233 -> 234 ;
# 235 [label="credit_history_critical/other existing credit <= 0.5\ngini = 0.435\nsamples = 25\nvalue = [8, 17]\nclass = good"] ;
# 234 -> 235 ;
# 236 [label="credit_usage <= 42.0\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = good"] ;
# 235 -> 236 ;
# 237 [label="gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = good"] ;
# 236 -> 237 ;
# 238 [label="purpose_radio/tv <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 236 -> 238 ;
# 239 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 238 -> 239 ;
# 240 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 238 -> 240 ;
# 241 [label="purpose_furniture/equipment <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = bad"] ;
# 235 -> 241 ;
# 242 [label="property_magnitude_life insurance <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = bad"] ;
# 241 -> 242 ;
# 243 [label="cc_age <= 26.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = bad"] ;
# 242 -> 243 ;
# 244 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 243 -> 244 ;
# 245 [label="cc_age <= 41.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 243 -> 245 ;
# 246 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 245 -> 246 ;
# 247 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 245 -> 247 ;
# 248 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 242 -> 248 ;
# 249 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 241 -> 249 ;
# 250 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 234 -> 250 ;
# 251 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 233 -> 251 ;
# 252 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 230 -> 252 ;
# 253 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = good"] ;
# 229 -> 253 ;
# 254 [label="current_balance <= 4458.5\ngini = 0.154\nsamples = 273\nvalue = [23, 250]\nclass = good"] ;
# 228 -> 254 ;
# 255 [label="purpose_repairs <= 0.5\ngini = 0.102\nsamples = 222\nvalue = [12, 210]\nclass = good"] ;
# 254 -> 255 ;
# 256 [label="cc_age <= 30.5\ngini = 0.088\nsamples = 217\nvalue = [10, 207]\nclass = good"] ;
# 255 -> 256 ;
# 257 [label="purpose_education <= 0.5\ngini = 0.188\nsamples = 76\nvalue = [8, 68]\nclass = good"] ;
# 256 -> 257 ;
# 258 [label="Average_Credit_Balance_500<=X<1000 <= 0.5\ngini = 0.169\nsamples = 75\nvalue = [7, 68]\nclass = good"] ;
# 257 -> 258 ;
# 259 [label="other_parties_guarantor <= 0.5\ngini = 0.134\nsamples = 69\nvalue = [5, 64]\nclass = good"] ;
# 258 -> 259 ;
# 260 [label="credit_usage <= 25.5\ngini = 0.112\nsamples = 67\nvalue = [4, 63]\nclass = good"] ;
# 259 -> 260 ;
# 261 [label="credit_history_delayed previously <= 0.5\ngini = 0.064\nsamples = 60\nvalue = [2, 58]\nclass = good"] ;
# 260 -> 261 ;
# 262 [label="cc_age <= 22.5\ngini = 0.034\nsamples = 57\nvalue = [1, 56]\nclass = good"] ;
# 261 -> 262 ;
# 263 [label="personal_status_male single <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = good"] ;
# 262 -> 263 ;
# 264 [label="gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = good"] ;
# 263 -> 264 ;
# 265 [label="residence_since <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 263 -> 265 ;
# 266 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 265 -> 266 ;
# 267 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 265 -> 267 ;
# 268 [label="gini = 0.0\nsamples = 49\nvalue = [0, 49]\nclass = good"] ;
# 262 -> 268 ;
# 269 [label="purpose_business <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 261 -> 269 ;
# 270 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 269 -> 270 ;
# 271 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 269 -> 271 ;
# 272 [label="property_magnitude_real estate <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = good"] ;
# 260 -> 272 ;
# 273 [label="job_high qualif/self emp/mgmt <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = good"] ;
# 272 -> 273 ;
# 274 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 273 -> 274 ;
# 275 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 273 -> 275 ;
# 276 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 272 -> 276 ;
# 277 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = bad"] ;
# 259 -> 277 ;
# 278 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 277 -> 278 ;
# 279 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 277 -> 279 ;
# 280 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = good"] ;
# 258 -> 280 ;
# 281 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 280 -> 281 ;
# 282 [label="employment_1<=X<4 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 280 -> 282 ;
# 283 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 282 -> 283 ;
# 284 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 282 -> 284 ;
# 285 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 257 -> 285 ;
# 286 [label="other_parties_co applicant <= 0.5\ngini = 0.028\nsamples = 141\nvalue = [2, 139]\nclass = good"] ;
# 256 -> 286 ;
# 287 [label="credit_history_delayed previously <= 0.5\ngini = 0.015\nsamples = 135\nvalue = [1, 134]\nclass = good"] ;
# 286 -> 287 ;
# 288 [label="gini = 0.0\nsamples = 122\nvalue = [0, 122]\nclass = good"] ;
# 287 -> 288 ;
# 289 [label="property_magnitude_car <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = good"] ;
# 287 -> 289 ;
# 290 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = good"] ;
# 289 -> 290 ;
# 291 [label="job_skilled <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = good"] ;
# 289 -> 291 ;
# 292 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 291 -> 292 ;
# 293 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 291 -> 293 ;
# 294 [label="residence_since <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = good"] ;
# 286 -> 294 ;
# 295 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 294 -> 295 ;
# 296 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = good"] ;
# 294 -> 296 ;
# 297 [label="current_balance <= 1275.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = good"] ;
# 255 -> 297 ;
# 298 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 297 -> 298 ;
# 299 [label="employment_1<=X<4 <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = bad"] ;
# 297 -> 299 ;
# 300 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 299 -> 300 ;
# 301 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 299 -> 301 ;
# 302 [label="employment_<1 <= 0.5\ngini = 0.338\nsamples = 51\nvalue = [11, 40]\nclass = good"] ;
# 254 -> 302 ;
# 303 [label="current_balance <= 4640.0\ngini = 0.24\nsamples = 43\nvalue = [6, 37]\nclass = good"] ;
# 302 -> 303 ;
# 304 [label="personal_status_female div/dep/mar <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = bad"] ;
# 303 -> 304 ;
# 305 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = bad"] ;
# 304 -> 305 ;
# 306 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = good"] ;
# 304 -> 306 ;
# 307 [label="cc_age <= 65.5\ngini = 0.142\nsamples = 39\nvalue = [3, 36]\nclass = good"] ;
# 303 -> 307 ;
# 308 [label="current_balance <= 10924.5\ngini = 0.1\nsamples = 38\nvalue = [2, 36]\nclass = good"] ;
# 307 -> 308 ;
# 309 [label="gini = 0.0\nsamples = 34\nvalue = [0, 34]\nclass = good"] ;
# 308 -> 309 ;
# 310 [label="credit_history_delayed previously <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = bad"] ;
# 308 -> 310 ;
# 311 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = bad"] ;
# 310 -> 311 ;
# 312 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = good"] ;
# 310 -> 312 ;
# 313 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 307 -> 313 ;
# 314 [label="current_balance <= 5523.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = bad"] ;
# 302 -> 314 ;
# 315 [label="credit_usage <= 9.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = good"] ;
# 314 -> 315 ;
# 316 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = bad"] ;
# 315 -> 316 ;
# 317 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = good"] ;
# 315 -> 317 ;
# 318 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = bad"] ;
# 314 -> 318 ;
# }

# %%
import graphiz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-fe43073bf171> in <module>()
# ----> 1 import graphiz
#
# ModuleNotFoundError: No module named 'graphiz'

# %%
print(graphiz.Source(dot_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b931dd9cc1ff> in <module>()
# ----> 1 print(graphiz.Source(dot_data))
#
# NameError: name 'graphiz' is not defined

# %%
# Since the train accuracy is 1 that means the model is overfit to the data
# To remove this we tune the hyperparameters for the model

# min_samples_split: The minimum number of instances that should be at a node 
# before the algorithm does a further split on it.

# min_impurity_decrease: The minimum percentage reduction in the impurity of 
# a set (as measured by gini index) required to make a split.

model1 = DecisionTreeClassifier(min_samples_split=10,min_impurity_decrease=0.005).fit(X_train, y_train)

# %%
# Train accuracy
model1.score(X_train, y_train)
# Out:
# 0.7675

# %%
# Test accuracy 
model1.score(X_test, y_test)
# Out:
# 0.73
